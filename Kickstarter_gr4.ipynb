# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 16, 8

from scipy.stats import norm
from scipy import stats

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %%
# importing the training and test data
KS_train =  pd.read_csv('KS_train_data.csv', sep=','  , engine='python')
KS_test =  pd.read_csv('KS_test_data.csv', sep=','  , engine='python')
print('Contents of Dataframe : ')
print(KS_train)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2962             assert self.data is not None
# -> 2963             return next(self.data)
#    2964         except csv.Error as e:
#
# Error: ',' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-92564343a0ec> in <module>
#       1 # importing the training and test data
#       2 KS_train =  pd.read_csv('KS_train_data.csv', sep=','  , engine='python')
# ----> 3 KS_test =  pd.read_csv('KS_test_data.csv', sep=','  , engine='python')
#       4 print('Contents of Dataframe : ')
#       5 print(KS_train)
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2458     def read(self, rows=None):
#    2459         try:
# -> 2460             content = self._get_lines(rows)
#    2461         except StopIteration:
#    2462             if self._first_chunk:
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _get_lines(self, rows)
#    3260
#    3261                         while True:
# -> 3262                             new_row = self._next_iter_line(row_num=self.pos + rows + 1)
#    3263                             rows += 1
#    3264
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2984                     msg += ". " + reason
#    2985
# -> 2986                 self._alert_malformed(msg, row_num)
#    2987             return None
#    2988
#
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in _alert_malformed(self, msg, row_num)
#    2941         """
#    2942         if self.error_bad_lines:
# -> 2943             raise ParserError(msg)
#    2944         elif self.warn_bad_lines:
#    2945             base = f"Skipping line {row_num}: "
#
# ParserError: ',' expected after '"'
